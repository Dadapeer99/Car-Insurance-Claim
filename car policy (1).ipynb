# %% [raw]
# The Dataset contains information on policyholders having the attributes like policy tenure, age of the car, age of the car owner, the population density of the city, make and model of the car, power, engine type, etc, and the target variable indicating whether the policyholder files a claim in the next 6 months or not.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("train.csv")
df1=pd.read_csv("test.csv")
print(df.shape)
print(df1.shape)
df.head(10)
# Out:
# (58592, 44)
# (39063, 43)
#   policy_id  policy_tenure  age_of_car  age_of_policyholder area_cluster  \
# 0   ID00001       0.515874        0.05             0.644231           C1
# 1   ID00002       0.672619        0.02             0.375000           C2
# 2   ID00003       0.841110        0.02             0.384615           C3
# 3   ID00004       0.900277        0.11             0.432692           C4
# 4   ID00005       0.596403        0.11             0.634615           C5
# 5   ID00006       1.018709        0.07             0.519231           C6
# 6   ID00007       0.097992        0.16             0.403846           C7
# 7   ID00008       0.509085        0.14             0.423077           C8
# 8   ID00009       0.282394        0.07             0.298077           C7
# 9   ID00010       0.566255        0.04             0.442308           C9
#
#    population_density  make segment model fuel_type  ... is_brake_assist  \
# 0                4990     1       A    M1       CNG  ...              No
# 1               27003     1       A    M1       CNG  ...              No
# 2                4076     1       A    M1       CNG  ...              No
# 3               21622     1      C1    M2    Petrol  ...             Yes
# 4               34738     2       A    M3    Petrol  ...              No
# 5               13051     3      C2    M4    Diesel  ...             Yes
# 6                6112     4      B2    M5    Diesel  ...              No
# 7                8794     1      B2    M6    Petrol  ...             Yes
# 8                6112     3      C2    M4    Diesel  ...             Yes
# 9               17804     1      B2    M7    Petrol  ...             Yes
#
#   is_power_door_locks is_central_locking  is_power_steering  \
# 0                  No                 No                Yes
# 1                  No                 No                Yes
# 2                  No                 No                Yes
# 3                 Yes                Yes                Yes
# 4                 Yes                Yes                Yes
# 5                 Yes                Yes                Yes
# 6                 Yes                Yes                Yes
# 7                 Yes                Yes                Yes
# 8                 Yes                Yes                Yes
# 9                 Yes                Yes                Yes
#
#   is_driver_seat_height_adjustable is_day_night_rear_view_mirror is_ecw  \
# 0                               No                            No     No
# 1                               No                            No     No
# 2                               No                            No     No
# 3                              Yes                           Yes    Yes
# 4                               No                           Yes    Yes
# 5                              Yes                            No    Yes
# 6                               No                            No    Yes
# 7                              Yes                           Yes    Yes
# 8                              Yes                            No    Yes
# 9                              Yes                           Yes    Yes
#
#   is_speed_alert ncap_rating is_claim
# 0            Yes           0        0
# 1            Yes           0        0
# 2            Yes           0        0
# 3            Yes           2        0
# 4            Yes           2        0
# 5            Yes           3        0
# 6            Yes           5        0
# 7            Yes           2        0
# 8            Yes           3        0
# 9            Yes           0        0
#
# [10 rows x 44 columns]

# %%
df["policy_tenure"].nunique()
# Out:
# 58591

# %%
pid=df1["policy_id"]

# %%
df=df.drop(columns="policy_id")
df1=df1.drop(columns="policy_id")

# %%
df["is_claim"].value_counts()
# Out:
# 0    54844
# 1     3748
# Name: is_claim, dtype: int64

# %%
# df["age_of_car"].value_counts()
df.dtypes
# Out:
# policy_tenure                       float64
# age_of_car                          float64
# age_of_policyholder                 float64
# area_cluster                         object
# population_density                    int64
# make                                  int64
# segment                              object
# model                                object
# fuel_type                            object
# max_torque                           object
# max_power                            object
# engine_type                          object
# airbags                               int64
# is_esc                               object
# is_adjustable_steering               object
# is_tpms                              object
# is_parking_sensors                   object
# is_parking_camera                    object
# rear_brakes_type                     object
# displacement                          int64
# cylinder                              int64
# transmission_type                    object
# gear_box                              int64
# steering_type                        object
# turning_radius                      float64
# length                                int64
# width                                 int64
# height                                int64
# gross_weight                          int64
# is_front_fog_lights                  object
# is_rear_window_wiper                 object
# is_rear_window_washer                object
# is_rear_window_defogger              object
# is_brake_assist                      object
# is_power_door_locks                  object
# is_central_locking                   object
# is_power_steering                    object
# is_driver_seat_height_adjustable     object
# is_day_night_rear_view_mirror        object
# is_ecw                               object
# is_speed_alert                       object
# ncap_rating                           int64
# is_claim                              int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# policy_tenure                       0
# age_of_car                          0
# age_of_policyholder                 0
# area_cluster                        0
# population_density                  0
# make                                0
# segment                             0
# model                               0
# fuel_type                           0
# max_torque                          0
# max_power                           0
# engine_type                         0
# airbags                             0
# is_esc                              0
# is_adjustable_steering              0
# is_tpms                             0
# is_parking_sensors                  0
# is_parking_camera                   0
# rear_brakes_type                    0
# displacement                        0
# cylinder                            0
# transmission_type                   0
# gear_box                            0
# steering_type                       0
# turning_radius                      0
# length                              0
# width                               0
# height                              0
# gross_weight                        0
# is_front_fog_lights                 0
# is_rear_window_wiper                0
# is_rear_window_washer               0
# is_rear_window_defogger             0
# is_brake_assist                     0
# is_power_door_locks                 0
# is_central_locking                  0
# is_power_steering                   0
# is_driver_seat_height_adjustable    0
# is_day_night_rear_view_mirror       0
# is_ecw                              0
# is_speed_alert                      0
# ncap_rating                         0
# is_claim                            0
# dtype: int64

# %%
c=0
num_cols=[]
for i in df:
    if df[i].dtype!="object":
        c+=1
        num_cols.append(i)
        print(i)
print(c)
# Out:
# policy_tenure
# age_of_car
# age_of_policyholder
# population_density
# make
# airbags
# displacement
# cylinder
# gear_box
# turning_radius
# length
# width
# height
# gross_weight
# ncap_rating
# is_claim
# 16

# %%
for i in df.columns[df.dtypes=="object"]:
    df[i]=le.fit_transform(df[i])

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split,cross_val_score
xt,xe,yt,ye=train_test_split(x,y,test_size=0.3,random_state=42)
xt.shape,xe.shape,yt.shape,ye.shape
# Out:
# ((41014, 42), (17578, 42), (41014,), (17578,))

# %%
from sklearn.metrics import confusion_matrix,classification_report,f1_score,accuracy_score,precision_score,recall_score

# %% [markdown]
# # Base Model

# %% [markdown]
# # Train data

# %%
def classify(model,x,y):
    model.fit(xt,yt)
    global p
    p=model.predict(xe)
    cf=confusion_matrix(ye,p)
    print("Confusion_matrix")
    print(cf)
    ac=cf.diagonal().sum()/cf.sum()*100
    return ac

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
lg_ac=classify(lg,x,y)
print("Accuracy")
print(lg_ac)
a=f1_score(ye,p)
b=recall_score(ye,p)
c=precision_score(ye,p)
print(f"F1-score - {a}\nRecall - {b}\nPrecision - {c}")
# Out:
# Confusion_matrix
# [[16417     0]
#  [ 1161     0]]
# Accuracy
# 93.39515303219935
# F1-score - 0.0
# Recall - 0.0
# Precision - 0.0

# %%
print(classification_report(ye,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97     16417
#            1       0.00      0.00      0.00      1161
#
#     accuracy                           0.93     17578
#    macro avg       0.47      0.50      0.48     17578
# weighted avg       0.87      0.93      0.90     17578

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt_ac=classify(dt,x,y)
print("Accuracy")
print(dt_ac)
print(f1_score(ye,p))
print(accuracy_score(ye,p))
a1=f1_score(ye,p)
b1=recall_score(ye,p)
c1=precision_score(ye,p)
print(f"F1-score - {a1}\nRecall - {b1}\nPrecision - {c1}")
# Out:
# Confusion_matrix
# [[15205  1212]
#  [ 1037   124]]
# Accuracy
# 87.205597906474
# 0.09931918301962354
# 0.87205597906474
# F1-score - 0.09931918301962354
# Recall - 0.10680447889750215
# Precision - 0.09281437125748503

# %%
print(classification_report(ye,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93     16417
#            1       0.09      0.11      0.10      1161
#
#     accuracy                           0.87     17578
#    macro avg       0.51      0.52      0.52     17578
# weighted avg       0.88      0.87      0.88     17578

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf_ac=classify(rf,x,y)
print("Accuracy")
print(rf_ac)
print(f1_score(ye,p))
print(accuracy_score(ye,p))
a2=f1_score(ye,p)
b2=recall_score(ye,p)
c2=precision_score(ye,p)
print(f"F1-score - {a2}\nRecall - {b2}\nPrecision - {c2}")
# Out:
# Confusion_matrix
# [[16340    77]
#  [ 1151    10]]
# Accuracy
# 93.01399476618501
# 0.016025641025641028
# 0.93013994766185
# F1-score - 0.016025641025641028
# Recall - 0.008613264427217916
# Precision - 0.11494252873563218

# %%
print(classification_report(ye,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     16417
#            1       0.11      0.01      0.02      1161
#
#     accuracy                           0.93     17578
#    macro avg       0.52      0.50      0.49     17578
# weighted avg       0.88      0.93      0.90     17578

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn_ac=classify(knn,x,y)
print("Accuracy")
print(knn_ac)
print(f1_score(ye,p))
print(accuracy_score(ye,p))
a3=f1_score(ye,p)
b3=recall_score(ye,p)
c3=precision_score(ye,p)
print(f"F1-score - {a3}\nRecall - {b3}\nPrecision - {c3}")
# Out:
# Confusion_matrix
# [[16367    50]
#  [ 1155     6]]
# Accuracy
# 93.14484014108545
# 0.009860312243221035
# 0.9314484014108545
# F1-score - 0.009860312243221035
# Recall - 0.00516795865633075
# Precision - 0.10714285714285714

# %%
print(classification_report(ye,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     16417
#            1       0.11      0.01      0.01      1161
#
#     accuracy                           0.93     17578
#    macro avg       0.52      0.50      0.49     17578
# weighted avg       0.88      0.93      0.90     17578

# %% [markdown]
# # SVM

# %%
# from sklearn.svm import SVC
# svm=SVC()
# svm_ac=classify(svm,x,y)
# print("Accuracy")
# print(svm_ac)
# print(f1_score(ye,p))

# %%
# print(classification_report(ye,p))

# %% [markdown]
# # Navive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
nb=MultinomialNB()
nb_ac=classify(nb,x,y)
print("Accuracy")
print(nb_ac)
print(f1_score(ye,p))
print(accuracy_score(ye,p))
a4=f1_score(ye,p)
b4=recall_score(ye,p)
c4=precision_score(ye,p)
print(f"F1-score - {a4}\nRecall - {b4}\nPrecision - {c4}")
# Out:
# Confusion_matrix
# [[6433 9984]
#  [ 425  736]]
# Accuracy
# 40.78393446353396
# 0.12389529500883764
# 0.4078393446353396
# F1-score - 0.12389529500883764
# Recall - 0.6339362618432386
# Precision - 0.06865671641791045

# %%
print(classification_report(ye,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.39      0.55     16417
#            1       0.07      0.63      0.12      1161
#
#     accuracy                           0.41     17578
#    macro avg       0.50      0.51      0.34     17578
# weighted avg       0.88      0.41      0.52     17578

# %% [markdown]
# # XGB

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier()
xgb_ac=classify(xgb,x,y)
print("Accuracy")
print(xgb_ac)
print(f1_score(ye,p))
print(accuracy_score(ye,p))
a5=f1_score(ye,p)
b5=recall_score(ye,p)
c5=precision_score(ye,p)
print(f"F1-score - {a5}\nRecall - {b5}\nPrecision - {c5}")
# Out:
# Confusion_matrix
# [[16411     6]
#  [ 1161     0]]
# Accuracy
# 93.36101945613835
# 0.0
# 0.9336101945613835
# F1-score - 0.0
# Recall - 0.0
# Precision - 0.0

# %%
print(classification_report(ye,p))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97     16417
#            1       0.00      0.00      0.00      1161
#
#     accuracy                           0.93     17578
#    macro avg       0.47      0.50      0.48     17578
# weighted avg       0.87      0.93      0.90     17578

# %%
algo=["logistic","decision tree","Random Forest","KNN","Naive Bayes","XGB"]
accuracy=[lg_ac,dt_ac,rf_ac,knn_ac,nb_ac,xgb_ac]
m=[a,a1,a2,a3,a4,a5]
precision=[c,c1,c2,c3,c4,c5]
recall=[b,b1,b2,b3,b4,b5]

# %%
basic=pd.DataFrame({"Algorithm":algo,"Accuracy":accuracy,"F1-score":m,"Precision":precision,"Recall":recall})
basic
# Out:
#        Algorithm   Accuracy  F1-score  Precision    Recall
# 0       logistic  93.395153  0.000000   0.000000  0.000000
# 1  decision tree  87.205598  0.099319   0.092814  0.106804
# 2  Random Forest  93.013995  0.016026   0.114943  0.008613
# 3            KNN  93.144840  0.009860   0.107143  0.005168
# 4    Naive Bayes  40.783934  0.123895   0.068657  0.633936
# 5            XGB  93.361019  0.000000   0.000000  0.000000

# %% [raw]
# #---
# From the basic model dataset we can conclude that there is F1-score,Precision and recall are approximately zero
# #--

# %% [markdown]
# # Class Imbalance Techniques
# # ----------------------------------------

# %% [markdown]
# # SMOTE Over Sampling

# %%
yt.value_counts()
# Out:
# 0    38427
# 1     2587
# Name: is_claim, dtype: int64

# %%
sns.countplot(y=yt,data=df)
# Out:
# <Axes: xlabel='count', ylabel='is_claim'>

# %%
from imblearn.over_sampling import SMOTE
over=SMOTE()
x_smote,y_smote=over.fit_resample(xt,yt)

# %%
y_smote.value_counts()
# Out:
# 1    38427
# 0    38427
# Name: is_claim, dtype: int64

# %%
sm_data=pd.concat([x_smote,y_smote],axis=1)
sm_data.shape
# Out:
# (76854, 43)

# %%
sns.countplot(y=y_smote,data=sm_data)
# Out:
# <Axes: xlabel='count', ylabel='is_claim'>

# %% [markdown]
# ## outlier treatment

# %%
fig,ax=plt.subplots(4,4,figsize=(20,25))
index=0
ax=ax.flatten()
for i in sm_data:
    if i in num_cols:
        sns.distplot(sm_data[i],ax=ax[index])
        index+=1
plt.show()

# %%
fig,ax=plt.subplots(4,4,figsize=(20,25))
index=0
ax=ax.flatten()
for i in df:
    if i in num_cols:
        sns.boxplot(df[i],ax=ax[index])
        ax[index].set_title(i)
        index+=1
plt.show()

# %%
for i in sm_data:
    if i in num_cols:
        print(i)
        print(sm_data[i].skew())
        print()
# Out:
# policy_tenure
# -0.20071763707574145
#
# age_of_car
# 1.03151668486302
#
# age_of_policyholder
# 0.6513239226605881
#
# population_density
# 1.7283024574702375
#
# make
# 1.2051298236822536
#
# airbags
# 0.8977030271544567
#
# displacement
# -0.13488381016491283
#
# cylinder
# -0.57385845634184
#
# gear_box
# 1.2054377137749899
#
# turning_radius
# 0.42779505062504447
#
# length
# 0.12247971705204366
#
# width
# -0.5397208683148615
#
# height
# 1.0234674171735316
#
# gross_weight
# 0.547251557000384
#
# ncap_rating
# 0.06380010286187629
#
# is_claim
# 0.0

# %%
num_col1=["policy_tenure","age_of_car","age_of_policyholder","population_density","turning_radius","length","width","height","gross_weight"]
num_col1
# Out:
# ['policy_tenure',
#  'age_of_car',
#  'age_of_policyholder',
#  'population_density',
#  'turning_radius',
#  'length',
#  'width',
#  'height',
#  'gross_weight']

# %%
# make,airbags,cylinder,make,gear_box,displacement,ncap_rating,is_claim-categorical

# %% [markdown]
# ## IQR

# %%
for i in sm_data:
    if i in ["age_of_car", "population_density","height"]:
        print(i)
        print("Skew Before",sm_data[i].skew())
        IQR = sm_data[i].quantile(0.75) - sm_data[i].quantile(0.25)
        print("IQR =", IQR)
        ub = sm_data[i].quantile(0.75) + 3 * IQR
        lb = sm_data[i].quantile(0.25) - 3 * IQR
        print("Upper boundary =", ub)
        print("Lower boundary =", lb)

        # Update values outside the boundaries
        sm_data[i]=np.where(sm_data[i]>ub,ub,
                        np.where(sm_data[i]<lb,lb,
                                sm_data[i]))
        print("Skew After",sm_data[i].skew())
        print()
#         data.loc[data[i] > ub, i] = ub
#         data.loc[data[i] < lb, i] = lb
# Out:
# age_of_car
# Skew Before 1.03151668486302
# IQR = 0.08
# Upper boundary = 0.33999999999999997
# Lower boundary = -0.22
# Skew After 0.7605543353731109
#
# population_density
# Skew Before 1.7283024574702375
# IQR = 20891.0
# Upper boundary = 89676.0
# Lower boundary = -56561.0
# Skew After 1.7283024574702375
#
# height
# Skew Before 1.0234674171735316
# IQR = 145.0
# Upper boundary = 2070.0
# Lower boundary = 1055.0
# Skew After 1.0234674171735316

# %% [markdown]
# ## normal distribution

# %%
norm=["policy_tenure","age_of_policyholder","turning_radius","length","width","gross_weight"]
for i in sm_data:
    if i in norm:
        ub=sm_data[i].mean()+3*sm_data[i].std()
        lb=sm_data[i].mean()-3*sm_data[i].std()
        sm_data[i]=np.where(sm_data[i]>ub,ub,
                            np.where(sm_data[i]<lb,lb,
                                    sm_data[i]))

# %%
for i in num_col1:
    print(i)
    print(sm_data[i].skew())
    print()
# Out:
# policy_tenure
# -0.20071763707574145
#
# age_of_car
# 0.7605543353731109
#
# age_of_policyholder
# 0.6310588828454888
#
# population_density
# 1.7283024574702375
#
# turning_radius
# 0.42779505062504447
#
# length
# 0.12247971705204366
#
# width
# -0.5397208683148615
#
# height
# 1.0234674171735316
#
# gross_weight
# 0.547251557000384

# %%
a=sm_data[["population_density","height"]]
print(a.skew())
b=np.sqrt(a)
print(b.skew())
# Out:
# population_density    1.728302
# height                1.023467
# dtype: float64
# population_density    0.867064
# height                0.966143
# dtype: float64

# %%
sm_data["population_density"]=np.sqrt(sm_data["population_density"])
sm_data["height"]=np.sqrt(sm_data["height"])

# %%
for i in num_col1:
    print(i)
    print(sm_data[i].skew())
    print()
# Out:
# policy_tenure
# -0.20071763707574145
#
# age_of_car
# 0.7605543353731109
#
# age_of_policyholder
# 0.6310588828454888
#
# population_density
# 0.8670637042252176
#
# turning_radius
# 0.42779505062504447
#
# length
# 0.12247971705204366
#
# width
# -0.5397208683148615
#
# height
# 0.96614304535188
#
# gross_weight
# 0.547251557000384

# %%
fig,ax=plt.subplots(3,3,figsize=(20,25))
index=0
ax=ax.flatten()
for i in sm_data:
    if i in num_col1:
        sns.distplot(sm_data[i],ax=ax[index])
        index+=1
plt.show()

# %%
fig,ax=plt.subplots(3,3,figsize=(10,10))
index=0
ax=ax.flatten()
for i in sm_data:
    if i in num_col1:
        sns.boxplot(sm_data[i],ax=ax[index])
        ax[index].set_title(i)
        index+=1
plt.show()

# %%
sm_data.shape
# Out:
# (76854, 43)

# %%
x_smote=sm_data.iloc[:,:-1]
y_smote=sm_data.iloc[:,-1]

# %%
xtr8,xte8,ytr8,yte8=train_test_split(x_smote,y_smote,test_size=0.2,random_state=100)
xtr8.shape,xte8.shape,ytr8.shape,yte8.shape
# Out:
# ((61483, 42), (15371, 42), (61483,), (15371,))

# %%
l=[lg,dt,rf,knn,nb,xgb]
l1=[]
f1=[]
precision=[]
recall=[]

for i in l:
    i.fit(x_smote,y_smote)
    print(i.__class__.__name__)
    pre=i.predict(xte8)
    cff1=confusion_matrix(yte8,pre)
    print(cff1)
    acc1=cff1.diagonal().sum()/cff1.sum()*100
    print(acc1)
    precision.append(precision_score(yte8,pre))
    recall.append(recall_score(yte8,pre))
    print()
    print(classification_report(yte8,pre))
    l1.append(acc1)
    f1score=f1_score(yte8,pre)
    f1.append(f1score)
# Out:
# LogisticRegression
# [[3994 3639]
#  [3351 4387]]
# 54.52475440765077
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.52      0.53      7633
#            1       0.55      0.57      0.56      7738
#
#     accuracy                           0.55     15371
#    macro avg       0.55      0.55      0.54     15371
# weighted avg       0.55      0.55      0.55     15371
#
# DecisionTreeClassifier
# [[7633    0]
#  [   0 7738]]
# 100.0
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7633
#            1       1.00      1.00      1.00      7738
#
#     accuracy                           1.00     15371
#    macro avg       1.00      1.00      1.00     15371
# weighted avg       1.00      1.00      1.00     15371
#
# RandomForestClassifier
# [[7633    0]
#  [   1 7737]]
# 99.99349424240452
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7633
#            1       1.00      1.00      1.00      7738
#
#     accuracy                           1.00     15371
#    macro avg       1.00      1.00      1.00     15371
# weighted avg       1.00      1.00      1.00     15371
#
# KNeighborsClassifier
# [[6049 1584]
#  [ 304 7434]]
# 87.71712965974888
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.79      0.87      7633
#            1       0.82      0.96      0.89      7738
#
#     accuracy                           0.88     15371
#    macro avg       0.89      0.88      0.88     15371
# weighted avg       0.89      0.88      0.88     15371
#
# MultinomialNB
# [[3727 3906]
#  [3470 4268]]
# 52.01353197579858
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.49      0.50      7633
#            1       0.52      0.55      0.54      7738
#
#     accuracy                           0.52     15371
#    macro avg       0.52      0.52      0.52     15371
# weighted avg       0.52      0.52      0.52     15371
#
# XGBClassifier
# [[7589   44]
#  [ 800 6938]]
# 94.50914058942163
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.95      7633
#            1       0.99      0.90      0.94      7738
#
#     accuracy                           0.95     15371
#    macro avg       0.95      0.95      0.94     15371
# weighted avg       0.95      0.95      0.94     15371

# %%
algo=["logistic","decision tree","Random Forest","KNN","Naive Bayes","XGB"]
basic=pd.DataFrame({"Algorithm":algo,"Accuracy":l1,"F1-score":f1,"Precision":precision,"Recall":recall})
basic
# Out:
#        Algorithm    Accuracy  F1-score  Precision    Recall
# 0       logistic   54.524754  0.556585   0.546599  0.566942
# 1  decision tree  100.000000  1.000000   1.000000  1.000000
# 2  Random Forest   99.993494  0.999935   1.000000  0.999871
# 3            KNN   87.717130  0.887324   0.824351  0.960713
# 4    Naive Bayes   52.013532  0.536450   0.522143  0.551564
# 5            XGB   94.509141  0.942663   0.993698  0.896614

# %% [raw]
# # After applying smote over sampling
# XGB has good accuracy and F1-score with respective parameters

# %% [markdown]
# # Imb learn over sampler

# %%
# from imblearn.over_sampling import RandomOverSampler
# r=RandomOverSampler()
# x_imb,y_imb=over.fit_resample(xt,yt)
# imb_data=pd.concat([x_imb,y_imb],axis=1)
# imb_data.shape

# %%
# yt.value_counts()

# %%
# y_imb.value_counts()

# %% [markdown]
# ## IQR

# %%
# for i in imb_data:
#     if i in ["age_of_car", "population_density"]:
#         print(i)
#         print("Skew Before",sm_data[i].skew())
#         IQR = imb_data[i].quantile(0.75) - imb_data[i].quantile(0.25)
#         print("IQR =", IQR)
#         ub = imb_data[i].quantile(0.75) + 3 * IQR
#         lb = imb_data[i].quantile(0.25) - 3 * IQR
#         print("Upper boundary =", ub)
#         print("Lower boundary =", lb)

#         # Update values outside the boundaries
#         imb_data[i]=np.where(imb_data[i]>ub,ub,
#                         np.where(imb_data[i]<lb,lb,
#                                 imb_data[i]))
#         print("Skew After",imb_data[i].skew())

# %% [markdown]
# ## normal_distribution

# %%
# norm=["policy_tenure","age_of_policyholder","turning_radius","length","width","gross_weight"]
# for i in imb_data:
#     if i in norm:
#         ub=imb_data[i].mean()+3*imb_data[i].std()
#         lb=imb_data[i].mean()-3*imb_data[i].std()
#         imb_data[i]=np.where(imb_data[i]>ub,ub,
#                             np.where(imb_data[i]<lb,lb,
#                                     imb_data[i]))

# %%
# for i in num_col1:
#     print(i)
#     print(imb_data[i].skew())
#     print()

# %%
# a=imb_data[["population_density","height"]]
# print(a.skew())
# b=np.sqrt(a)
# print(b.skew())
# imb_data["population_density"]=np.sqrt(imb_data["population_density"])
# imb_data["height"]=np.sqrt(imb_data["height"])

# %%
# for i in num_col1:
#     print(i)
#     print(imb_data[i].skew())
#     print()

# %%
# x_imb=imb_data.iloc[:,:-1]
# y_imb=imb_data.iloc[:,-1]

# %%
# xtr7,xte7,ytr7,yte7=train_test_split(x_imb,y_imb,test_size=0.2,random_state=100)
# xtr7.shape,xte7.shape,ytr7.shape,yte7.shape

# %%
# l=[lg,dt,rf,knn,nb,xgb]
# l1=[]
# f1=[]
# precision=[]
# recall=[]
# for i in l:
#     i.fit(x_imb,y_imb)
#     print(i.__class__.__name__)
#     pre=i.predict(xte7)
#     cff1=confusion_matrix(yte7,pre)
#     print(cff1)
#     acc1=cff1.diagonal().sum()/cff1.sum()*100
#     print(acc1)
#     precision.append(precision_score(yte7,pre))
#     recall.append(recall_score(yte7,pre))
#     print()
#     print(classification_report(yte7,pre))
#     l1.append(acc1)
#     f1score=f1_score(yte7,pre)
#     f1.append(f1score)

# %%
# algo=["logistic","decision tree","Random Forest","KNN","Naive Bayes","XGB"]
# basic=pd.DataFrame({"Algorithm":algo,"Accuracy":l1,"F1-score":f1,"Precision":precision,"Recall":recall})
# basic

# %% [raw]
# Imb learn also has similar accuracy with related to xgb and other parameters

# %% [markdown]
# # IMb learn under

# %%
# from imblearn.under_sampling import RandomUnderSampler
# u=RandomUnderSampler()
# x_imb_u,y_imb_u=u.fit_resample(xt,yt)

# %%
# xtr6,xte6,ytr6,yte6=train_test_split(x_imb_u,y_imb_u,test_size=0.2,random_state=100)
# xtr6.shape,xte6.shape,ytr6.shape,yte6.shape

# %%
# l=[lg,dt,rf,knn,nb,xgb]
# l1=[]
# f1=[]
# precision=[]
# recall=[]
# for i in l:
#     i.fit(x_imb_u,y_imb_u)
#     print(i.__class__.__name__)
#     pre=i.predict(xte6)
#     cff1=confusion_matrix(yte6,pre)
#     print(cff1)
#     acc1=cff1.diagonal().sum()/cff1.sum()*100
#     print(acc1)
#     precision.append(precision_score(yte6,pre))
#     recall.append(recall_score(yte6,pre))
#     print()
#     print(classification_report(yte6,pre))
#     l1.append(acc1)
#     f1score=f1_score(yte6,pre)
#     f1.append(f1score)

# %%
# algo=["logistic","decision tree","Random Forest","KNN","Naive Bayes","XGB"]
# basic=pd.DataFrame({"Algorithm":algo,"Accuracy":l1,"F1-score":f1,"Precison":precision,"Recall":recall})
# basic

# %% [markdown]
# # Feature_selection

# %% [markdown]
# # Recursive Feature elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()

# %%
rfe = RFE(estimator=dtree, n_features_to_select=5)

# %%
rfe.fit(sm_data.iloc[:,:-1],sm_data.iloc[:,-1])
# Out:
# RFE(estimator=DecisionTreeClassifier(), n_features_to_select=5)

# %%
rfe.support_
# Out:
# array([ True,  True,  True,  True, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
rf1=pd.DataFrame({"feature":list(rfe.support_),"col":list(sm_data.iloc[:,:-1].columns)})
rf1
# Out:
#     feature                               col
# 0      True                     policy_tenure
# 1      True                        age_of_car
# 2      True               age_of_policyholder
# 3      True                      area_cluster
# 4     False                population_density
# 5     False                              make
# 6     False                           segment
# 7      True                             model
# 8     False                         fuel_type
# 9     False                        max_torque
# 10    False                         max_power
# 11    False                       engine_type
# 12    False                           airbags
# 13    False                            is_esc
# 14    False            is_adjustable_steering
# 15    False                           is_tpms
# 16    False                is_parking_sensors
# 17    False                 is_parking_camera
# 18    False                  rear_brakes_type
# 19    False                      displacement
# 20    False                          cylinder
# 21    False                 transmission_type
# 22    False                          gear_box
# 23    False                     steering_type
# 24    False                    turning_radius
# 25    False                            length
# 26    False                             width
# 27    False                            height
# 28    False                      gross_weight
# 29    False               is_front_fog_lights
# 30    False              is_rear_window_wiper
# 31    False             is_rear_window_washer
# 32    False           is_rear_window_defogger
# 33    False                   is_brake_assist
# 34    False               is_power_door_locks
# 35    False                is_central_locking
# 36    False                 is_power_steering
# 37    False  is_driver_seat_height_adjustable
# 38    False     is_day_night_rear_view_mirror
# 39    False                            is_ecw
# 40    False                    is_speed_alert
# 41    False                       ncap_rating

# %%
m=rf1[rf1["feature"]==True]
print(m["col"].to_string(index=False))
# Out:
#       policy_tenure
#          age_of_car
# age_of_policyholder
#        area_cluster
#               model

# %%
# data2=sm_data[m["col"]]
# data2=pd.concat([data2,sm_data["is_claim"]],axis=1)
# data2.head()
data2=sm_data[["policy_tenure","age_of_car","age_of_policyholder","population_density","model","is_claim"]]

# %%
data2.to_csv("final.csv")

# %%
data2.shape
# Out:
# (76854, 6)

# %%
xg=data2.iloc[:,:-1]
yg=data2.iloc[:,-1]

# %%
xt4,xte4,yt4,yte4=train_test_split(xg,yg,test_size=0.2)
xt4.shape,xte4.shape,yt4.shape,yte4.shape
# Out:
# ((61483, 5), (15371, 5), (61483,), (15371,))

# %%
l=[lg,dt,rf,knn,nb,xgb]
l1=[]
f1=[]
precision=[]
recall=[]
for i in l:
    i.fit(xt4,yt4)
    print(i.__class__.__name__)
    pre=i.predict(xte4)
    cff1=confusion_matrix(yte4,pre)
    print(cff1)
    acc1=cff1.diagonal().sum()/cff1.sum()*100
    print(acc1)
    precision.append(precision_score(yte4,pre))
    recall.append(recall_score(yte4,pre))
    print()
    print(classification_report(yte4,pre))
    l1.append(acc1)
    f1score=f1_score(yte4,pre)
    f1.append(f1score)
# Out:
# LogisticRegression
# [[4358 3327]
#  [3055 4631]]
# 58.480255025697744
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.57      0.58      7685
#            1       0.58      0.60      0.59      7686
#
#     accuracy                           0.58     15371
#    macro avg       0.58      0.58      0.58     15371
# weighted avg       0.58      0.58      0.58     15371
#
# DecisionTreeClassifier
# [[6972  713]
#  [ 623 7063]]
# 91.30830785244942
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91      7685
#            1       0.91      0.92      0.91      7686
#
#     accuracy                           0.91     15371
#    macro avg       0.91      0.91      0.91     15371
# weighted avg       0.91      0.91      0.91     15371
#
# RandomForestClassifier
# [[7361  324]
#  [ 644 7042]]
# 93.70242664758311
#
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      7685
#            1       0.96      0.92      0.94      7686
#
#     accuracy                           0.94     15371
#    macro avg       0.94      0.94      0.94     15371
# weighted avg       0.94      0.94      0.94     15371
#
# KNeighborsClassifier
# [[5282 2403]
#  [ 641 7045]]
# 80.19647387938326
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.69      0.78      7685
#            1       0.75      0.92      0.82      7686
#
#     accuracy                           0.80     15371
#    macro avg       0.82      0.80      0.80     15371
# weighted avg       0.82      0.80      0.80     15371
#
# MultinomialNB
# [[3815 3870]
#  [3202 4484]]
# 53.99128228482207
#
#               precision    recall  f1-score   support
#
#            0       0.54      0.50      0.52      7685
#            1       0.54      0.58      0.56      7686
#
#     accuracy                           0.54     15371
#    macro avg       0.54      0.54      0.54     15371
# weighted avg       0.54      0.54      0.54     15371
#
# XGBClassifier
# [[7607   78]
#  [ 884 6802]]
# 93.74146119315594
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94      7685
#            1       0.99      0.88      0.93      7686
#
#     accuracy                           0.94     15371
#    macro avg       0.94      0.94      0.94     15371
# weighted avg       0.94      0.94      0.94     15371

# %%
algo=["logistic","decision tree","Random Forest","KNN","Naive Bayes","XGB"]
basic=pd.DataFrame({"Algorithm":algo,"Accuracy":l1,"F1-score":f1,"Precision":precision,"Recall":recall})
basic
# Out:
#        Algorithm   Accuracy  F1-score  Precision    Recall
# 0       logistic  58.480255  0.592048   0.581930  0.602524
# 1  decision tree  91.308308  0.913595   0.908308  0.918944
# 2  Random Forest  93.702427  0.935690   0.956014  0.916211
# 3            KNN  80.196474  0.822342   0.745660  0.916602
# 4    Naive Bayes  53.991282  0.559102   0.536749  0.583398
# 5            XGB  93.741461  0.933956   0.988663  0.884986

# %%
pre=xgb.predict(xte4)

# %%
cm=confusion_matrix(yte4,pre)
sns.heatmap(cm,annot=True,fmt="d",cmap="Spectral")
plt.title("Confusion Matrix")
plt.show()

# %%
# Hence we conclude as XGB as better model

# %% [markdown]
# # test_data

# %%
for i in df1.columns[df1.dtypes=="object"]:
    df1[i]=le.fit_transform(df1[i])

# %%
tes1=df1[["policy_tenure","age_of_car","age_of_policyholder","population_density","model"]]

# %%
tes1
# Out:
#        policy_tenure  age_of_car  age_of_policyholder  population_density  \
# 0           0.341732        0.00             0.586538                4076
# 1           0.307241        0.13             0.442308                8794
# 2           0.327924        0.12             0.451923                8794
# 3           0.782654        0.01             0.461538               34738
# 4           1.233404        0.02             0.634615               34738
# ...              ...         ...                  ...                 ...
# 39058       0.047982        0.15             0.740385               27003
# 39059       1.224838        0.05             0.509615                8794
# 39060       0.520287        0.12             0.355769               13051
# 39061       1.172391        0.08             0.644231               34738
# 39062       0.094030        0.12             0.307692                8794
#
#        model
# 0          0
# 1          7
# 2          4
# 3          0
# 4          0
# ...      ...
# 39058      7
# 39059      5
# 39060      8
# 39061      3
# 39062      5
#
# [39063 rows x 5 columns]

# %%
# MODEL FOR XGB
p1=dt.predict(tes1)
res=pd.DataFrame({"policy_id":pid,"is_claim":p1})
res.to_csv(r"C:\Users\asdad\OneDrive\Desktop\newdemo\Car_policy\basics-files\result.csv",index=False)

# %% [markdown]
# # AUC-ROC CURVE

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
# rf.fit(xt4,yt4)
pre=xgb.predict(xte4)

# %%
m=xgb.predict_proba(xte4)
m
# Out:
# array([[0.9264825 , 0.07351752],
#        [0.91091233, 0.08908767],
#        [0.10644829, 0.8935517 ],
#        ...,
#        [0.00121206, 0.99878794],
#        [0.34965467, 0.6503453 ],
#        [0.94785035, 0.05214965]], dtype=float32)

# %%
roc=roc_auc_score(yte4,pre)
roc
# Out:
# 0.9374180230521624

# %%
# fpr,tpr,threshold=roc_curve(yte4,rf.predict_proba(xte4)[:,1])
fpr,tpr,threshold=roc_curve(yte4,m[:,1])
# fpr,tpr,threshold=roc_curve(yte4,pre)

# %%
plt.plot(fpr,tpr)
plt.title("AUC-ROC curve")
plt.xlabel("fpr")
plt.ylabel("tpr")
plt.show()

# %%
import joblib
joblib.dump(xgb,'xgb.pkl')
# Out:
# ['xgb.pkl']

# %%
model = joblib.load('xgb.pkl')

# %%
data2.head()
# Out:
#    policy_tenure  age_of_car  age_of_policyholder  population_density  model  \
# 0       0.975712        0.07             0.384615           93.776330      7
# 1       0.509869        0.10             0.576923          270.979704      5
# 2       1.100863        0.07             0.432692           73.552702      7
# 3       0.793827        0.06             0.721154           93.776330      7
# 4       0.012367        0.01             0.403846          186.381330      7
#
#    is_claim
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0

# %%
model.predict([[0.97512,0.07,0.38,93.77,7]])
# Out:
# array([1])

# %%
model.predict([[0.509869,0.10,0.23,270.979704,5]])
# Out:
# array([0])

# %% [markdown]
# #  Chi square test

# %%
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
chiTest=SelectKBest(score_func=chi2,k="all")

# %%
c=chiTest.fit(sm_data.iloc[:,:-1],sm_data.iloc[:,-1])

# %%
chi=pd.DataFrame({"feature":list(c.scores_),"col":list(sm_data.iloc[:,:-1].columns)})
chi
# Out:
#         feature                               col
# 0    604.267905                     policy_tenure
# 1     16.782487                        age_of_car
# 2      2.322129               age_of_policyholder
# 3    195.666860                      area_cluster
# 4   2503.980816                population_density
# 5      1.387256                              make
# 6      4.982619                           segment
# 7     61.420217                             model
# 8     16.382907                         fuel_type
# 9    186.728727                        max_torque
# 10    47.325851                         max_power
# 11     0.052469                       engine_type
# 12     3.263220                           airbags
# 13     0.063005                            is_esc
# 14    24.867527            is_adjustable_steering
# 15     0.042804                           is_tpms
# 16     0.146467                is_parking_sensors
# 17     3.537642                 is_parking_camera
# 18     0.057551                  rear_brakes_type
# 19  1438.773516                      displacement
# 20     3.033907                          cylinder
# 21     4.779032                 transmission_type
# 22     0.127908                          gear_box
# 23    52.737298                     steering_type
# 24     0.040550                    turning_radius
# 25   441.282596                            length
# 26   318.724703                             width
# 27     0.110797                            height
# 28    66.956136                      gross_weight
# 29    15.933177               is_front_fog_lights
# 30     0.000722              is_rear_window_wiper
# 31     0.000722             is_rear_window_washer
# 32     0.187002           is_rear_window_defogger
# 33     9.380961                   is_brake_assist
# 34     5.395720               is_power_door_locks
# 35     5.395720                is_central_locking
# 36     0.041636                 is_power_steering
# 37    12.693063  is_driver_seat_height_adjustable
# 38     8.530023     is_day_night_rear_view_mirror
# 39     5.395720                            is_ecw
# 40     0.087939                    is_speed_alert
# 41     1.285454                       ncap_rating

# %%
m1=chi[chi["feature"]>=14]
print(m1["col"].to_string(index=False))
len(m1["col"])
# Out:
#          policy_tenure
#             age_of_car
#           area_cluster
#     population_density
#                  model
#              fuel_type
#             max_torque
#              max_power
# is_adjustable_steering
#           displacement
#          steering_type
#                 length
#                  width
#           gross_weight
#    is_front_fog_lights
# 15

# %%
m1
# Out:
#         feature                               col
# 0    604.267905                     policy_tenure
# 1     16.782487                        age_of_car
# 3    195.666860                      area_cluster
# 4   2503.980816                population_density
# 7     61.420217                             model
# 8     16.382907                         fuel_type
# 9    186.728727                        max_torque
# 10    47.325851                         max_power
# 14    24.867527            is_adjustable_steering
# 19  1438.773516                      displacement
# 23    52.737298                     steering_type
# 25   441.282596                            length
# 26   318.724703                             width
# 28    66.956136                      gross_weight
# 29    15.933177               is_front_fog_lights
# 37    12.693063  is_driver_seat_height_adjustable

# %%
m1=sm_data[["policy_tenure","age_of_car","area_cluster","population_density","model","max_torque","max_power","is_adjustable_steering","displacement","steering_type","length","width","gross_weight","is_front_fog_lights","is_claim"]]

# %%
# data3=sm_data[m1["col"]]
# data3=pd.concat([data3,sm_data["is_claim"]],axis=1)
data3=m1

# %%
data3.head()
# Out:
#    policy_tenure  age_of_car  area_cluster  population_density  model  \
# 0       0.975712        0.07            20           93.776330      7
# 1       0.509869        0.10             1          270.979704      5
# 2       1.100863        0.07             4           73.552702      7
# 3       0.793827        0.06            20           93.776330      7
# 4       0.012367        0.01            17          186.381330      7
#
#    max_torque  max_power  is_adjustable_steering  displacement  steering_type  \
# 0           0          6                       1          1197              0
# 1           4          0                       1          1493              2
# 2           0          6                       1          1197              0
# 3           0          6                       1          1197              0
# 4           0          6                       1          1197              0
#
#    length   width  gross_weight  is_front_fog_lights  is_claim
# 0  3845.0  1735.0        1335.0                    1         1
# 1  4300.0  1790.0        1720.0                    1         0
# 2  3845.0  1735.0        1335.0                    1         0
# 3  3845.0  1735.0        1335.0                    1         0
# 4  3845.0  1735.0        1335.0                    1         0

# %%
data3["is_claim"].value_counts()
# Out:
# 1    38427
# 0    38427
# Name: is_claim, dtype: int64

# %%
data3.shape
# Out:
# (76854, 15)

# %%
c1=data3.iloc[:,:-1]
c2=data3.iloc[:,-1]

# %%
xt5,xte5,yt5,yte5=train_test_split(c1,c2,test_size=0.2)
xt5.shape,xte5.shape,yt5.shape,yte5.shape
# Out:
# ((61483, 14), (15371, 14), (61483,), (15371,))

# %%
l=[lg,dt,rf,knn,nb,xgb]
l1=[]
f1=[]
precision=[]
recall=[]
for i in l:
    i.fit(xt5,yt5)
    print(i.__class__.__name__)
    pre=i.predict(xte5)
    cff1=confusion_matrix(yte5,pre)
    print(cff1)
    acc1=cff1.diagonal().sum()/cff1.sum()*100
    print(acc1)
    precision.append(precision_score(yte5,pre))
    recall.append(recall_score(yte5,pre))
    print()
    print(classification_report(yte5,pre))
    l1.append(acc1)
    f1score=f1_score(yte5,pre)
    f1.append(f1score)
# Out:
# LogisticRegression
# [[3501 4204]
#  [3229 4437]]
# 51.64270379285668
#
#               precision    recall  f1-score   support
#
#            0       0.52      0.45      0.49      7705
#            1       0.51      0.58      0.54      7666
#
#     accuracy                           0.52     15371
#    macro avg       0.52      0.52      0.51     15371
# weighted avg       0.52      0.52      0.51     15371
#
# DecisionTreeClassifier
# [[6853  852]
#  [ 742 6924]]
# 89.62982239281764
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      7705
#            1       0.89      0.90      0.90      7666
#
#     accuracy                           0.90     15371
#    macro avg       0.90      0.90      0.90     15371
# weighted avg       0.90      0.90      0.90     15371
#
# RandomForestClassifier
# [[6603 1102]
#  [1132 6534]]
# 85.46613753171557
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86      7705
#            1       0.86      0.85      0.85      7666
#
#     accuracy                           0.85     15371
#    macro avg       0.85      0.85      0.85     15371
# weighted avg       0.85      0.85      0.85     15371
#
# KNeighborsClassifier
# [[5202 2503]
#  [1476 6190]]
# 74.11359052761695
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.68      0.72      7705
#            1       0.71      0.81      0.76      7666
#
#     accuracy                           0.74     15371
#    macro avg       0.75      0.74      0.74     15371
# weighted avg       0.75      0.74      0.74     15371
#
# MultinomialNB
# [[3799 3906]
#  [3596 4070]]
# 51.193806518769115
#
#               precision    recall  f1-score   support
#
#            0       0.51      0.49      0.50      7705
#            1       0.51      0.53      0.52      7666
#
#     accuracy                           0.51     15371
#    macro avg       0.51      0.51      0.51     15371
# weighted avg       0.51      0.51      0.51     15371
#
# XGBClassifier
# [[7339  366]
#  [1280 6386]]
# 89.29152299785311
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      7705
#            1       0.95      0.83      0.89      7666
#
#     accuracy                           0.89     15371
#    macro avg       0.90      0.89      0.89     15371
# weighted avg       0.90      0.89      0.89     15371

# %%
algo=["logistic","decision tree","Random Forest","KNN","Naive Bayes","XGB"]
basic=pd.DataFrame({"Algorithm":algo,"Accuracy":l1,"F1-score":f1,"Precision":precision,"Recall":recall})
basic
# Out:
#        Algorithm   Accuracy  F1-score  Precision    Recall
# 0       logistic  51.642704  0.544183   0.513482  0.578789
# 1  decision tree  89.629822  0.896775   0.890432  0.903209
# 2  Random Forest  85.466138  0.854006   0.855684  0.852335
# 3            KNN  74.113591  0.756770   0.712067  0.807462
# 4    Naive Bayes  51.193807  0.520394   0.510281  0.530916
# 5            XGB  89.291523  0.885837   0.945794  0.833029

# %%
pre=xgb.predict(xte5)

# %%
cm=confusion_matrix(yte5,pre)
sns.heatmap(cm,annot=True,fmt="d",cmap="Spectral")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# # AUC ROC CURVE

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score

# %%
# rf.fit(xt4,yt4)
pre=xgb.predict(xte5)

# %%
roc=roc_auc_score(yte5,pre)
roc
# Out:
# 0.8927636683583748

# %%
m=xgb.predict_proba(xte5)
m
# Out:
# array([[0.7740267 , 0.22597332],
#        [0.9935178 , 0.00648219],
#        [0.92195296, 0.07804702],
#        ...,
#        [0.9027697 , 0.09723031],
#        [0.7527951 , 0.24720491],
#        [0.7121421 , 0.2878579 ]], dtype=float32)

# %%
fpr,tpr,threshold=roc_curve(yte5,xgb.predict_proba(xte5)[:,1])
# fpr,tpr,threshold=roc_curve(yte4,m[:,1])
# fpr,tpr,threshold=roc_curve(yte4,pre)

# %%
plt.plot(fpr,tpr)
plt.title("AUC-ROC curve")
plt.xlabel("fpr")
plt.ylabel("tpr")
plt.show()

# %%
import joblib
joblib.dump(xgb,'xgb2.pkl')
# Out:
# ['xgb2.pkl']

# %%
data3.to_csv("feature.csv")

# %%
data3.head()
# Out:
#    policy_tenure  age_of_car  area_cluster  population_density  model  \
# 0       0.975712        0.07            20           93.776330      7
# 1       0.509869        0.10             1          270.979704      5
# 2       1.100863        0.07             4           73.552702      7
# 3       0.793827        0.06            20           93.776330      7
# 4       0.012367        0.01            17          186.381330      7
#
#    max_torque  max_power  is_adjustable_steering  displacement  steering_type  \
# 0           0          6                       1          1197              0
# 1           4          0                       1          1493              2
# 2           0          6                       1          1197              0
# 3           0          6                       1          1197              0
# 4           0          6                       1          1197              0
#
#    length   width  gross_weight  is_front_fog_lights  is_claim
# 0  3845.0  1735.0        1335.0                    1         1
# 1  4300.0  1790.0        1720.0                    1         0
# 2  3845.0  1735.0        1335.0                    1         0
# 3  3845.0  1735.0        1335.0                    1         0
# 4  3845.0  1735.0        1335.0                    1         0

# %%
model = joblib.load('xgb2.pkl')

# %%
model.predict([[0.50,0.10,1,270.979704,5,4,0,1,1493,2,4300,1790,1720,1]])
# Out:
# array([0])

# %%
# Conckusuin:xgb accuracy decreases after feature selection and and added to 
# deployment of flask

# %% [markdown]
# # Deploy XGB MODEL INTO FLASK

# %%
from flask import Flask,render_template,request
import numpy as np
import pickle
import joblib
app=Flask(__name__)
model = joblib.load('xgb2.pkl')

@app.route('/')
def home():
    return render_template('index1.html')


@app.route('/predict',methods=['POST'])
def predict():
    
    features = [float(x) for x in request.form.values()]
    final_features = [np.array(features)]
    print(final_features)
    prediction = model.predict(final_features)

    output = prediction[0]
    if output==0:
        output="You are eligible for car policy"
    else:
        output="Your are not eligible for car ploicy "
    return render_template('index1.html',res=output)
if __name__ == "__main__":
    app.run(host="localhost", port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:5000
# Press CTRL+C to quit

# %%
# data["is_claim"].value_counts()

# %%
# import pandas as pd

# # Assuming df is your DataFrame
# # Check the current value counts
# value_counts = df["is_claim"].value_counts()
# print("Current Value Counts:")
# print(value_counts)

# # Increase the count of '1' by a specified amount (e.g., by 100)
# increase_amount = 100
# rows_to_increase = 1  # The value '1'

# # Identify the rows with '1' and increase their count
# rows_with_one = df[df["is_claim"] == rows_to_increase].sample(increase_amount, replace=True)
# df = pd.concat([df, rows_with_one], axis=0)

# # Check the updated value counts
# updated_value_counts = df["is_claim"].value_counts()
# print("\nUpdated Value Counts:")
# print(updated_value_counts)

# %%
# data["is_claim"].value_counts()

# %%
# amount = 54844
# percentage = 0.10 # 10 percent as a decimal

# result = amount * percentage

# print(int(result))
# a=10
# b=7.5
# w=(b/a)
# w#2 percentage of 10(part/whole)*100

# %%
# # using xgb classifier
# xn=data.iloc[:,:-1]
# yn=data.iloc[:,-1]

# %%
# xt2,xte2,yt2,yte2=train_test_split(xo,yo,test_size=0.2)
# xt2.shape,xte2.shape,yt2.shape,yte2.shape

# %%
# xgb.fit(xt2,yt2)
# xgb_p=xgb.predict(xte2)
# xgb_cf=confusion_matrix(yte2,xgb_p)
# print(xgb_cf)
# xgb_ac=xgb_cf.diagonal().sum()/xgb_cf.sum()*100
# print(xgb_ac)
# print(accuracy_score(yte2,xgb_p))

# %%
# dt_ac=dt_c.diagonal().sum()/dt_c.sum()*100
# dt_ac
