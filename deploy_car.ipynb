# %%
from flask import Flask,render_template,request
import numpy as np
import pickle
import joblib
app=Flask(__name__)
model = joblib.load('dt.pkl')

@app.route('/')
def home():
    return render_template('index.html')


@app.route('/predict',methods=['POST'])
def predict():
        s1=float(request.form["policy_tenure"])
        s2=float(request.form["age_of_car"])
        s3=float(request.form["age_of_policyholder"])
        s4=float(request.form["population_density"])
        s5=float(request.form["model"])
        res=model.predict([[s1,s2,s3,s4,s5]])[0]
        out=""
        if res==0:
            out="Eligible for car policy"
        else:
            out="Not eligible for car ploicy"
        return render_template('index.html',res=out)
app.run()

# %%
from flask import Flask,render_template,request
import numpy as np
import pickle
import joblib
app=Flask(__name__)
model = joblib.load('dt.pkl')

@app.route('/')
def home():
    return render_template('index.html')


@app.route('/predict',methods=['POST'])
def predict():
    
    features = [float(x) for x in request.form.values()]
    final_features = [np.array(features)]
    print(final_features)
    prediction = model.predict(final_features)

    output = prediction[0]
    if output==0:
        output="You are eligible for car policy"
    else:
        output="Your are not eligible for car ploicy "
    return render_template('index.html',res=output)
if __name__ == "__main__":
    app.run(host="localhost", port=5000)

# %%
from flask import Flask,render_template,request
import numpy as np
import pickle
import joblib
app=Flask(__name__)
model = joblib.load('xgb2.pkl')

@app.route('/')
def home():
    return render_template('index1.html')


@app.route('/predict',methods=['POST'])
def predict():
    
    features = [float(x) for x in request.form.values()]
    final_features = [np.array(features)]
    print(final_features)
    prediction = model.predict(final_features)

    output = prediction[0]
    if output==0:
        output="You are eligible for car policy"
    else:
        output="Your are not eligible for car ploicy "
    return render_template('index1.html',res=output)
if __name__ == "__main__":
    app.run(host="localhost", port=5000)
